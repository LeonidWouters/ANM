# %%
import pandas as pd
import geopandas as gpd

# %%
# Load the data
haushalte = pd.read_csv(r"C:\Users\leoni\Documents\HSLU\5. Semester\Analytics in nachhaltiger Mobilität\ANM\Daten\haushalte.csv", sep=";", encoding="ISO-8859-1")
# Out:
# C:\Users\leoni\AppData\Local\Temp\ipykernel_13616\44210061.py:2: DtypeWarning: Columns (53,66) have mixed types. Specify dtype option on import or set low_memory=False.
#   haushalte = pd.read_csv(r"C:\Users\leoni\Documents\HSLU\5. Semester\Analytics in nachhaltiger Mobilität\ANM\Daten\haushalte.csv", sep=";", encoding="ISO-8859-1")

# %%
haushalte.head()
# Out:
#      HHNR        WM  DMOD    intwdate  sprache   ZEIT_HH       W_X        W_Y  \
# 0  110001  1.391603     2  05.03.2021        2  7.133333  6.559870  46.549366
# 1  110008  0.484276     2  03.03.2021        2  7.166667  6.635652  46.785591
# 2  110011  0.161184     3  04.02.2021        1  9.516667  9.112485  47.451677
# 3  110024  0.411859     2  07.04.2021        1  3.866667  7.499629  46.897868
# 4  110026  1.036084     1  14.04.2021        1  5.383333  8.658613  47.724048
#
#    W_QAL  W_BFS  ...  f80211e f80211f f80211g f80300  f80400a  f80400b  \
# 0      1   5624  ...      -99     -99     -99    -99      -99      -99
# 1      1   5938  ...      -99     -99     -99    -99      -99      -99
# 2      1   3408  ...        0       0       0      1        2      -99
# 3      1    861  ...      -99     -99     -99    -99      -99      -99
# 4      1   2939  ...      -99     -99     -99    -99      -99      -99
#
#    f80400c  f80400d  f20601  ALTEL
# ...

# %%
haushalte.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55018 entries, 0 to 55017
# Data columns (total 94 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   HHNR                 55018 non-null  int64
#  1   WM                   55018 non-null  float64
#  2   DMOD                 55018 non-null  int64
#  3   intwdate             55018 non-null  object
#  4   sprache              55018 non-null  int64
#  5   ZEIT_HH              55018 non-null  float64
#  6   W_X                  55018 non-null  float64
#  7   W_Y                  55018 non-null  float64
#  8   W_QAL                55018 non-null  int64
#  9   W_BFS                55018 non-null  int64
#  10  W_PLZ                55018 non-null  int64
#  11  W_ORT                55018 non-null  object
#  12  W_STR                54994 non-null  object
#  13  W_HNR                54876 non-null  object
#  14  W_SPRACHE            55018 non-null  int64
# ...

# %%
haushalte = haushalte[['HHNR',
                       'W_BFS',
                       'W_PLZ',
                       'W_ORT',
                       'W_KANTON',
                       'W_OEV_KLASSE',
                       'W_stadt_land_2012',
                       'hhgr',
                       'f20601']]

# %%
haushalte.head()
# Out:
#      HHNR  W_BFS  W_PLZ              W_ORT  W_KANTON  W_OEV_KLASSE  \
# 0  110001   5624   1030           Bussigny        22             3
# 1  110008   5938   1400  Yverdon-les-Bains        22             2
# 2  110011   3408   9247              Henau        17             4
# 3  110024    861   3123               Belp         2             3
# 4  110026   2939   8207       Schaffhausen        14             3
#
#    W_stadt_land_2012  hhgr  f20601
# 0                  1     2       5
# 1                  1     3       3
# 2                  1     4     -99
# 3                  2     4     -99
# 4                  1     1       2

# %%
haushalte.rename(columns={'W_BFS': 'BFS_NR',
                          'W_PLZ': 'PLZ',
                          'W_ORT': 'ORT',
                          'W_KANTON': 'KANTON',
                          'W_OEV_KLASSE': 'OEV_GUETEKLASSE',
                          'W_stadt_land_2012': 'STADT_LAND',
                          'hhgr': 'HAUSHALTSGROESSE',
                          'f20601': 'HAUSHALTSEINKOMMEN'}, inplace=True)
# Out:
# C:\Users\leoni\AppData\Local\Temp\ipykernel_13616\3013823972.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   haushalte.rename(columns={'W_BFS': 'BFS_NR',

# %%
haushalte.head()
# Out:
#      HHNR  BFS_NR   PLZ                ORT  KANTON  OEV_GUETEKLASSE  \
# 0  110001    5624  1030           Bussigny      22                3
# 1  110008    5938  1400  Yverdon-les-Bains      22                2
# 2  110011    3408  9247              Henau      17                4
# 3  110024     861  3123               Belp       2                3
# 4  110026    2939  8207       Schaffhausen      14                3
#
#    STADT_LAND  HAUSHALTSGROESSE  HAUSHALTSEINKOMMEN
# 0           1                 2                   5
# 1           1                 3                   3
# 2           1                 4                 -99
# 3           2                 4                 -99
# 4           1                 1                   2

# %%
zielpersonen = pd.read_csv(r"C:\Users\leoni\Documents\HSLU\5. Semester\Analytics in nachhaltiger Mobilität\ANM\Daten\zielpersonen.csv", sep=";", encoding="ISO-8859-1")

# %%
zielpersonen.head(5)
# Out:
#      HHNR        WP  alter  gesl  proxi  sprache  DMOD    zeit_zp        BTag  \
# 0  110001  1.606924     57     1      2        2     2  27.916667  05.03.2021
# 1  110008  0.655876     57     1      2        2     2  29.933333  03.03.2021
# 2  110011  0.279462     16     2      2        1     3  11.183333  04.02.2021
# 3  110024  0.746432     17     2      2        1     2  13.966667  07.04.2021
# 4  110026  0.525001     53     2      2        1     1  24.333333  14.04.2021
#
#         USTag  ... AU_KANTON  AU_BFS  AU_PLZ  AU_AGGLO2012  \
# 0  25.02.2021  ...       -99     -99     -99           -99
# 1  07.02.2021  ...       -99     -99     -99           -99
# 2  13.01.2021  ...       -99     -99     -99           -99
# 3  23.03.2021  ...       -99     -99     -99           -99
# 4  06.04.2021  ...       -99     -99     -99           -99
#
#    AU_AGGLO_GROESSE2012  AU_staedt_char_2012  AU_stat_stadt_2012  \
# 0                   -99                  -99                 -99
# ...

# %%
zielpersonen = zielpersonen[['HHNR',
                             'alter',
                             'gesl',
                             'f40120',
                             'zivil',
                             'HAUSB3']]

# %%
zielpersonen.head(5)
# Out:
#      HHNR  alter  gesl  f40120  zivil  HAUSB3
# 0  110001     57     1       4      4       2
# 1  110008     57     1       2      2       1
# 2  110011     16     2       2      1       1
# 3  110024     17     2       2      1       1
# 4  110026     53     2       4      1       2

# %%
wege_inland = pd.read_csv(r"C:\Users\leoni\Documents\HSLU\5. Semester\Analytics in nachhaltiger Mobilität\ANM\Daten\wegeinland.csv", sep=";", encoding="ISO-8859-1")

# %%
wege_inland.head(5)
# Out:
#      HHNR        WP  AUSNR  WEGNR  DMOD  f51100  f51400 f51100time f51400time  \
# 0  110001  1.606924      1      1     2     555     565    9:15:00    9:25:00
# 1  110001  1.606924      1      2     2     575     580    9:35:00    9:40:00
# 2  110001  1.606924      1      3     2     610     620   10:10:00   10:20:00
# 3  110001  1.606924      2      4     2     750     760   12:30:00   12:40:00
# 4  110001  1.606924      2      5     2     810     825   13:30:00   13:45:00
#
#    pseudo  ...  w_luftlin  w_rdist  wmittel1  wmittel1a  wmittel2 wmittel2a  \
# 0       1  ...   0.333127    0.413         8          2         8         2
# 1       1  ...   0.863416    1.483         8          2         8         2
# 2       1  ...   1.123565    1.407         8          2         8         2
# 3       1  ...   2.167349    3.973         8          2         8         2
# 4       1  ...   3.127501    4.811         8          2         8         2
#
#   wzweck1 wzweck2  wzweck3  w_dist_obj2
# ...

# %%
weg_geo = weg_geo = gpd.read_file(r"C:\Users\leoni\Documents\HSLU\5. Semester\Analytics in nachhaltiger Mobilität\ANM\Daten\routen_ch_plausi.gpkg")

# %%
weg_geo.head(5)
# Out:
#      HHNR                  GIS_E_ID  f51300  rdist    length      gppkm  \
# 0  110001  2021-03-05T10:38:49.722Z       9  0.413  0.415152  69.853994
# 1  110001  2021-03-05T10:51:07.068Z       9  1.483  1.489093  85.286789
# 2  110001  2021-03-05T10:42:47.309Z       9  1.407  1.411074  66.615903
# 3  110001  2021-03-05T10:43:49.602Z       9  3.973  3.984491  60.986464
# 4  110001  2021-03-05T10:48:02.854Z       9  4.811  4.822324  51.012747
#
#                                             geometry
# 0  LINESTRING (6.56052 46.54921, 6.56053 46.54920...
# 1  LINESTRING (6.56418 46.54890, 6.56390 46.54910...
# 2  LINESTRING (6.57353 46.55356, 6.57357 46.55346...
# 3  LINESTRING (6.56052 46.54921, 6.56053 46.54920...
# 4  LINESTRING (6.55259 46.56777, 6.55336 46.56776...

# %%
weg_geo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 162669 entries, 0 to 162668
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   HHNR      162669 non-null  object
#  1   GIS_E_ID  162669 non-null  object
#  2   f51300    162669 non-null  int64
#  3   rdist     162669 non-null  float64
#  4   length    162669 non-null  float64
#  5   gppkm     162669 non-null  float64
#  6   geometry  162669 non-null  geometry
# dtypes: float64(3), geometry(1), int64(1), object(2)
# memory usage: 8.7+ MB

# %%
weg_geo[weg_geo['length'] > 200]
# Out:
#           HHNR                  GIS_E_ID  f51300    rdist      length  \
# 221     110262  2021-04-17T08:36:21.385Z       9  272.134  272.484568
# 477     110563  2021-04-27T18:42:35.314Z       9  261.504  261.970000
# 617     110767  2021-02-06T11:39:11.068Z      10  260.268  260.572154
# 1204    111563  2021-04-06T17:13:40.652Z       9  238.756  238.956135
# 2773    113774  2021-03-26T13:29:53.484Z      11  199.789  200.120723
# ...        ...                       ...     ...      ...         ...
# 160817  457828  2022-01-02T11:57:49.916Z      11  204.114  204.658951
# 161426  458578  2021-12-13T08:45:31.423Z      10  212.078  212.749008
# 161619  458817  2022-01-24T13:59:37.723Z      10  215.053  215.282827
# 161620  458817  2022-01-24T14:01:49.323Z      10  213.917  214.149947
# 161659  458857  2022-01-09T12:16:22.613Z      10  230.089  230.638289
#
#             gppkm                                           geometry
# ...

# %%
weg_geo[weg_geo["GIS_E_ID"] == '2021-04-17T08:36:21.385Z'].explore(
    tiles="CartoDB positron",  # use "CartoDB positron" tiles
    cmap="Set1",  # use "Set1" matplotlib colormap
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
